# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# # Simple APIs
#
# ## Random User and Fruitvice API Examples
#
# Estimated time needed: **25** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Load and use RandomUser API, using `RandomUser()` Python library
# *   Load and use Fruitvice API, using `requests` Python library

# %% [markdown]
# The purpose of this notebook is to provide more examples on how to use simple APIs. As you have already learned from previous videos and notebooks, API stands for Application Programming Interface and is a software intermediary that allows two applications to talk to each other.
#
# The advantages of using APIs:
#
# *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more\
#     productive.
# *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#     independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#
# *   **Security**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data\
#     breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01#intro) can be found here.
#
# Another example of simple API we will use in this notebook is Fruitvice application. The Fruitvice API webservice which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The webservice is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
#
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01) page.

# %% [markdown]
# ## **Get Methods**
#
# *   get_cell()
# *   get_city()
# *   get_dob()
# *   get_email()
# *   get_first_name()
# *   get_full_name()
# *   get_gender()
# *   get_id()
# *   get_id_number()
# *   get_id_type()
# *   get_info()
# *   get_last_name()
# *   get_login_md5()
# *   get_login_salt()
# *   get_login_sha1()
# *   get_login_sha256()
# *   get_nat()
# *   get_password()
# *   get_phone()
# *   get_picture()
# *   get_postcode()
# *   get_registered()
# *   get_state()
# *   get_street()
# *   get_username()
# *   get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... done
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5067 sha256=3b8ba1d3ba119e8005014438d6cbce32f32edb56bd14fbf30fc1f2117b83279a
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/21/10/7b/c13bc3e24a3c1000a34554802ad8aa0ff27df56366998a0473
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x7f23f327c290>,
#  <randomuser.RandomUser at 0x7f23f327c2d0>,
#  <randomuser.RandomUser at 0x7f23f327c310>,
#  <randomuser.RandomUser at 0x7f23f327c350>,
#  <randomuser.RandomUser at 0x7f23f327c390>,
#  <randomuser.RandomUser at 0x7f23f327c410>,
#  <randomuser.RandomUser at 0x7f23f327c450>,
#  <randomuser.RandomUser at 0x7f23f327c490>,
#  <randomuser.RandomUser at 0x7f23f327c4d0>,
#  <randomuser.RandomUser at 0x7f23f327c3d0>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
name = r.get_full_name()

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Maja Poulsen   maja.poulsen@example.com
# Vladimir Blanchard   vladimir.blanchard@example.com
# Amine Høgli   amine.hogli@example.com
# Maurice Fabre   maurice.fabre@example.com
# Sofie Pedersen   sofie.pedersen@example.com
# Melike Çörekçi   melike.corekci@example.com
# Vilho Eskola   vilho.eskola@example.com
# Selma Christensen   selma.christensen@example.com
# Margaritha Meunier   margaritha.meunier@example.com
# Otto Karvonen   otto.karvonen@example.com

# %% [markdown]
# ## Exercise 1
#
# In this Exercise, generate photos of the random 5 users.

# %%
## Write your code here
for user in r.generate_users(5):
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/75.jpg
# https://randomuser.me/api/portraits/men/76.jpg
# https://randomuser.me/api/portraits/men/20.jpg
# https://randomuser.me/api/portraits/women/21.jpg
# https://randomuser.me/api/portraits/women/83.jpg

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(100):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                 Name  Gender           City              State  \
# 0   Lawrence Chapman    male        Mcallen            Indiana
# 1          Gül Çetin  female          Aydın          Gaziantep
# 2      Melanie Morin  female      Altendorf               Vaud
# 3       Emily Renard  female        Tecknau               Jura
# 4       James da Paz    male  Guaratinguetá  Rio Grande do Sul
# ..               ...     ...            ...                ...
# 95      Lylou Moulin  female  Saint-Étienne              Paris
# 96     Scarlett Hall  female          Derby            Rutland
# 97      Malik Fortin    male        Keswick            Ontario
# 98     Lucien Perrin    male       Bordeaux              Indre
# 99        Isa Løland  female        Nesbyen               Oslo
#
#                            Email                       DOB  \
# 0   lawrence.chapman@example.com  1975-06-29T07:22:46.187Z
# 1          gul.cetin@example.com  1966-12-23T13:01:15.954Z
# 2      melanie.morin@example.com  1968-10-19T12:49:22.677Z
# 3       emily.renard@example.com  1955-03-31T14:52:55.976Z
# 4        james.dapaz@example.com  1979-08-22T12:18:15.836Z
# ..                           ...                       ...
# 95      lylou.moulin@example.com  1994-08-18T01:42:41.385Z
# 96     scarlett.hall@example.com  1968-07-10T02:09:23.971Z
# 97      malik.fortin@example.com  1947-08-06T03:43:34.035Z
# 98     lucien.perrin@example.com  1991-06-18T03:00:09.692Z
# 99        isa.loland@example.com  1963-05-04T10:26:47.772Z
#
#                                              Picture
# 0     https://randomuser.me/api/portraits/men/46.jpg
# 1   https://randomuser.me/api/portraits/women/46.jpg
# 2   https://randomuser.me/api/portraits/women/77.jpg
# 3   https://randomuser.me/api/portraits/women/58.jpg
# 4     https://randomuser.me/api/portraits/men/57.jpg
# ..                                               ...
# 95  https://randomuser.me/api/portraits/women/41.jpg
# 96  https://randomuser.me/api/portraits/women/91.jpg
# 97    https://randomuser.me/api/portraits/men/89.jpg
# 98    https://randomuser.me/api/portraits/men/90.jpg
# 99  https://randomuser.me/api/portraits/women/79.jpg
#
# [100 rows x 7 columns]

# %%
df1 = pd.DataFrame(get_users())  
df1
# Out:
#                  Name  Gender            City                   State  \
# 0   Naja Christiansen  female         Brondby              Syddanmark
# 1     Aldalgisa Gomes  female        Brasília                  Paraná
# 2     Florence Grewal  female      Wellington            Saskatchewan
# 3        Lewis Martin    male          Nelson              West Coast
# 4     Avery Hernandez  female         Preston            Lincolnshire
# ..                ...     ...             ...                     ...
# 95       Teresa Welch  female       Ashbourne                Monaghan
# 96        Bruno Denis    male       Zeglingen  Appenzell Ausserrhoden
# 97         Hanny Keck  female  Hameln-Pyrmont     Nordrhein-Westfalen
# 98      Thorben Brühl    male        Weinheim                  Berlin
# 99     William Larsen    male      Nykøbing F             Nordjylland
#
#                             Email                       DOB  \
# 0   naja.christiansen@example.com  1961-06-03T18:22:38.377Z
# 1     aldalgisa.gomes@example.com  1980-04-13T13:57:17.748Z
# 2     florence.grewal@example.com  1958-06-04T13:02:06.120Z
# 3        lewis.martin@example.com  1968-04-01T14:18:04.229Z
# 4     avery.hernandez@example.com  1994-07-05T03:07:08.779Z
# ..                            ...                       ...
# 95       teresa.welch@example.com  1987-04-29T23:53:02.875Z
# 96        bruno.denis@example.com  1958-10-23T22:19:26.942Z
# 97         hanny.keck@example.com  1962-01-28T12:20:24.263Z
# 98      thorben.bruhl@example.com  1952-05-15T23:35:14.311Z
# 99     william.larsen@example.com  1984-12-01T08:02:31.440Z
#
#                                              Picture
# 0   https://randomuser.me/api/portraits/women/79.jpg
# 1   https://randomuser.me/api/portraits/women/60.jpg
# 2   https://randomuser.me/api/portraits/women/82.jpg
# 3     https://randomuser.me/api/portraits/men/54.jpg
# 4   https://randomuser.me/api/portraits/women/42.jpg
# ..                                               ...
# 95  https://randomuser.me/api/portraits/women/55.jpg
# 96    https://randomuser.me/api/portraits/men/45.jpg
# 97  https://randomuser.me/api/portraits/women/83.jpg
# 98     https://randomuser.me/api/portraits/men/5.jpg
# 99    https://randomuser.me/api/portraits/men/88.jpg
#
# [100 rows x 7 columns]

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruitvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruitvice](https://www.fruityvice.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01) API data using `requests.get("url")` function. The data is in a json format.

# %%
data = requests.get("https://www.fruityvice.com/api/fruit/all")

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
pd.DataFrame(results)
# Out:
#          genus          name  id           family             order  \
# 0        Malus         Apple   6         Rosaceae           Rosales
# 1       Prunus       Apricot  35         Rosaceae           Rosales
# 2         Musa        Banana   1         Musaceae      Zingiberales
# 3        Rubus    Blackberry  64         Rosaceae           Rosales
# 4     Fragaria     Blueberry  33         Rosaceae           Rosales
# 5       Prunus        Cherry   9         Rosaceae              None
# 6        Durio        Durian  60        Malvaceae          Malvales
# 7        Ficus           Fig  68         Moraceae           Rosales
# 8        Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 9        Vitis        Grapes  47         Vitaceae           Vitales
# 10       Malus    GreenApple  72         Rosaceae           Rosales
# 11     Psidium         Guava  37        Myrtaceae          Myrtales
# 12     Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 13      Citrus         Lemon  26         Rutaceae        Sapindales
# 14      Citrus          Lime  44         Rutaceae        Sapindales
# 15   Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 16      Litchi        Lychee  67      Sapindaceae        Sapindales
# 17   Mangifera         Mango  27    Anacardiaceae        Sapindales
# 18     Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 19      Citrus        Orange   2         Rutaceae        Sapindales
# 20      Carica        Papaya  42       Caricaceae         Caricacea
# 21  Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 22       Pyrus          Pear   4         Rosaceae           Rosales
# 23   Diospyros     Persimmon  52        Ebenaceae           Rosales
# 24      Ananas     Pineapple  10     Bromeliaceae            Poales
# 25      Prunus          Plum  71         Rosaceae           Rosales
# 26       Rubus     Raspberry  23         Rosaceae           Rosales
# 27    Fragaria    Strawberry   3         Rosaceae           Rosales
# 28     Solanum        Tomato   5       Solanaceae         Solanales
# 29    Spondias          Umbu  73    Anacardiaceae                 0
# 30   Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#                                            nutritions
# 0   {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1   {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2   {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 3   {'carbohydrates': 9, 'protein': 1.3, 'fat': 0....
# 4   {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 5   {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 6   {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...
# 7   {'carbohydrates': 19, 'protein': 0.8, 'fat': 0...
# 8   {'carbohydrates': 10, 'protein': 0.9, 'fat': 0...
# 9   {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 10  {'carbohydrates': 3.1, 'protein': 0.4, 'fat': ...
# 11  {'carbohydrates': 14, 'protein': 2.6, 'fat': 1...
# 12  {'carbohydrates': 15, 'protein': 1.1, 'fat': 0...
# 13  {'carbohydrates': 9, 'protein': 1.1, 'fat': 0....
# 14  {'carbohydrates': 8.4, 'protein': 0.3, 'fat': ...
# 15  {'carbohydrates': 11.3, 'protein': 0.75, 'fat'...
# 16  {'carbohydrates': 17, 'protein': 0.8, 'fat': 0...
# 17  {'carbohydrates': 15, 'protein': 0.82, 'fat': ...
# 18  {'carbohydrates': 8, 'protein': 0, 'fat': 0, '...
# 19  {'carbohydrates': 8.3, 'protein': 1, 'fat': 0....
# 20  {'carbohydrates': 11, 'protein': 0, 'fat': 0.4...
# 21  {'carbohydrates': 22.4, 'protein': 2.2, 'fat':...
# 22  {'carbohydrates': 15, 'protein': 0.4, 'fat': 0...
# 23  {'carbohydrates': 18, 'protein': 0, 'fat': 0, ...
# 24  {'carbohydrates': 13.12, 'protein': 0.54, 'fat...
# 25  {'carbohydrates': 11.4, 'protein': 0.7, 'fat':...
# 26  {'carbohydrates': 12, 'protein': 1.2, 'fat': 0...
# 27  {'carbohydrates': 5.5, 'protein': 0.8, 'fat': ...
# 28  {'carbohydrates': 3.9, 'protein': 0.9, 'fat': ...
# 29  {'carbohydrates': 0, 'protein': 0, 'fat': 0, '...
# 30  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#          genus          name  id           family             order  \
# 0        Malus         Apple   6         Rosaceae           Rosales
# 1       Prunus       Apricot  35         Rosaceae           Rosales
# 2         Musa        Banana   1         Musaceae      Zingiberales
# 3        Rubus    Blackberry  64         Rosaceae           Rosales
# 4     Fragaria     Blueberry  33         Rosaceae           Rosales
# 5       Prunus        Cherry   9         Rosaceae              None
# 6        Durio        Durian  60        Malvaceae          Malvales
# 7        Ficus           Fig  68         Moraceae           Rosales
# 8        Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 9        Vitis        Grapes  47         Vitaceae           Vitales
# 10       Malus    GreenApple  72         Rosaceae           Rosales
# 11     Psidium         Guava  37        Myrtaceae          Myrtales
# 12     Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 13      Citrus         Lemon  26         Rutaceae        Sapindales
# 14      Citrus          Lime  44         Rutaceae        Sapindales
# 15   Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 16      Litchi        Lychee  67      Sapindaceae        Sapindales
# 17   Mangifera         Mango  27    Anacardiaceae        Sapindales
# 18     Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 19      Citrus        Orange   2         Rutaceae        Sapindales
# 20      Carica        Papaya  42       Caricaceae         Caricacea
# 21  Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 22       Pyrus          Pear   4         Rosaceae           Rosales
# 23   Diospyros     Persimmon  52        Ebenaceae           Rosales
# 24      Ananas     Pineapple  10     Bromeliaceae            Poales
# 25      Prunus          Plum  71         Rosaceae           Rosales
# 26       Rubus     Raspberry  23         Rosaceae           Rosales
# 27    Fragaria    Strawberry   3         Rosaceae           Rosales
# 28     Solanum        Tomato   5       Solanaceae         Solanales
# 29    Spondias          Umbu  73    Anacardiaceae                 0
# 30   Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#     nutritions.carbohydrates  nutritions.protein  nutritions.fat  \
# 0                      11.40                0.30            0.40
# 1                       3.90                0.50            0.10
# 2                      22.00                1.00            0.20
# 3                       9.00                1.30            0.40
# 4                       5.50                0.00            0.40
# 5                      12.00                1.00            0.30
# 6                      27.10                1.50            5.30
# 7                      19.00                0.80            0.30
# 8                      10.00                0.90            0.60
# 9                      18.10                0.72            0.16
# 10                      3.10                0.40            0.10
# 11                     14.00                2.60            1.00
# 12                     15.00                1.10            0.50
# 13                      9.00                1.10            0.30
# 14                      8.40                0.30            0.10
# 15                     11.30                0.75            0.34
# 16                     17.00                0.80            0.44
# 17                     15.00                0.82            0.38
# 18                      8.00                0.00            0.00
# 19                      8.30                1.00            0.20
# 20                     11.00                0.00            0.40
# 21                     22.40                2.20            0.70
# 22                     15.00                0.40            0.10
# 23                     18.00                0.00            0.00
# 24                     13.12                0.54            0.12
# 25                     11.40                0.70            0.28
# 26                     12.00                1.20            0.70
# 27                      5.50                0.80            0.40
# 28                      3.90                0.90            0.20
# 29                      0.00                0.00            0.00
# 30                      8.00                0.60            0.20
#
#     nutritions.calories  nutritions.sugar
# 0                    52             10.30
# 1                    15              3.20
# 2                    96             17.20
# 3                    40              4.50
# 4                    29              5.40
# 5                    50              8.00
# 6                   147              6.75
# 7                    74             16.00
# 8                    44              0.00
# 9                    69             15.48
# 10                   21              6.40
# 11                   68              9.00
# 12                   61              9.00
# 13                   29              2.50
# 14                   25              1.70
# 15                   50              5.74
# 16                   66             15.00
# 17                   60             13.70
# 18                   34              8.00
# 19                   43              8.20
# 20                   43              1.00
# 21                   97             11.20
# 22                   57             10.00
# 23                   81             18.00
# 24                   50              9.85
# 25                   46              9.92
# 26                   53              4.40
# 27                   29              5.40
# 28                   74              2.60
# 29                    0              0.00
# 30                   30              6.00

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
#
# In this Exercise, find out how many calories are contained in a banana.

# %%
# Write your code here
banana = df2.loc[df2["name"] == "Banana"]
banana.iloc[0]['nutritions.calories']
# Out:
# 96

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://github.com/public-apis/public-apis#animals) contains a list of free public APIs. Choose any API of your interest and use it to load/extract some information, as shown in the example above.
#
# 1.  Using `requests.get("url")` function, load your data.

# %%
# Write your code here

data2 = requests.get(url='https://api.energidataservice.dk/dataset/CapacityPerMunicipality?limit')

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://www.fishwatch.gov/api/species")
# ```
#
# </details>

# %% [markdown]
# 2.  Retrieve results using `json.loads()` function.

# %%
# Write your code here
results2 = json.loads(data2.text)
results3 = results2["records"] 
results3

df = pd.DataFrame()
# Out:
# [{'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '1',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 0.18,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': None,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 9,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 0},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '101',
#   'CapacityGe100MW': 150.0,
#   'CapacityLt100MW': 193.949997,
#   'OffshoreWindCapacity': 40.0,
#   'OnshoreWindCapacity': 10.654,
#   'SolarPowerCapacity': 22.411961,
#   'NumberGenerationUnitsGe100MW': 1,
#   'NumberGenerationUnitsLt100MW': 8,
#   'NumberOffshoreWindGenerators': 20,
#   'NumberOnshoreWindGenerators': 13,
#   'NumberSolarPanels': 1429},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '147',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': None,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 2.038,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 0,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 117},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '151',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 3.887,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 6.5481,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 6,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 651},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '153',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 0.04,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 5.5,
#   'SolarPowerCapacity': 3.02648,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 1,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 1,
#   'NumberSolarPanels': 282},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '155',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 0.03,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 1.1977,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 1,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 214},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '157',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': None,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 3.32548,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 0,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 360},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '159',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 1.983,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 4.2501,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 3,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 651},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '161',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 41.790001,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 0.9,
#   'SolarPowerCapacity': 2.1604,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 3,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 3,
#   'NumberSolarPanels': 319},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '163',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': None,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 3.3906,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 0,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 424},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '165',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': None,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 1.6957,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 0,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 178},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '167',
#   'CapacityGe100MW': 699.0,
#   'CapacityLt100MW': 117.064003,
#   'OffshoreWindCapacity': 10.8,
#   'OnshoreWindCapacity': 2.005,
#   'SolarPowerCapacity': 5.7879,
#   'NumberGenerationUnitsGe100MW': 2,
#   'NumberGenerationUnitsLt100MW': 3,
#   'NumberOffshoreWindGenerators': 3,
#   'NumberOnshoreWindGenerators': 4,
#   'NumberSolarPanels': 585},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '169',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 1.042,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 0.85,
#   'SolarPowerCapacity': 8.88908,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 2,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 1,
#   'NumberSolarPanels': 639},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '173',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 41.172001,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 3.26305,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 8,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 425},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '175',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': None,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 2.1503,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 0,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 335},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '183',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': None,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 0.011,
#   'SolarPowerCapacity': 2.44197,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 0,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 1,
#   'NumberSolarPanels': 215},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '185',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 0.922,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 3.17092,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 1,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 565},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '187',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': None,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 0.001,
#   'SolarPowerCapacity': 0.9788,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 0,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 1,
#   'NumberSolarPanels': 170},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '190',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 0.353,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 3.17808,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 2,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 606},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '201',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 4.697,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 2.753,
#   'SolarPowerCapacity': 3.70678,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 10,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 6,
#   'NumberSolarPanels': 623},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '210',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 1.348,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 3.2637,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 3,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 490},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '217',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 74.255501,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 0.046,
#   'SolarPowerCapacity': 4.89656,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 10,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 3,
#   'NumberSolarPanels': 697},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '219',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 85.594002,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 4.087,
#   'SolarPowerCapacity': 7.19198,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 8,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 12,
#   'NumberSolarPanels': 974},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '223',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 16.367001,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 2.12638,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 3,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 258},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '230',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 3.824,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': 5.30378,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 9,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 762},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '240',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 13.641,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 0.137,
#   'SolarPowerCapacity': 5.74896,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 7,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 4,
#   'NumberSolarPanels': 1058},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '250',
#   'CapacityGe100MW': 520.0,
#   'CapacityLt100MW': 163.671997,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 3.041,
#   'SolarPowerCapacity': 5.236,
#   'NumberGenerationUnitsGe100MW': 2,
#   'NumberGenerationUnitsLt100MW': 9,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 13,
#   'NumberSolarPanels': 946},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '253',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 1.285,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 0.371,
#   'SolarPowerCapacity': 6.96686,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 4,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 3,
#   'NumberSolarPanels': 923},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '259',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 43.047001,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 3.988,
#   'SolarPowerCapacity': 13.60446,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 14,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 12,
#   'NumberSolarPanels': 1203},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '260',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 0.015,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 4.182,
#   'SolarPowerCapacity': 4.7448,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 1,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 11,
#   'NumberSolarPanels': 758},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '265',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 34.935001,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 7.865,
#   'SolarPowerCapacity': 12.82037,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 4,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 22,
#   'NumberSolarPanels': 1594},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '269',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 3.5915,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 0.616,
#   'SolarPowerCapacity': 2.92258,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 3,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 4,
#   'NumberSolarPanels': 645},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '270',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 17.523001,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 0.738,
#   'SolarPowerCapacity': 6.0767,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 6,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 23,
#   'NumberSolarPanels': 1112},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '306',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 13.072,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 5.1171,
#   'SolarPowerCapacity': 6.62422,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 14,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 43,
#   'NumberSolarPanels': 1149},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '316',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 8.728,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 59.279099,
#   'SolarPowerCapacity': 45.05019,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 12,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 70,
#   'NumberSolarPanels': 1462},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '320',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 7.71,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 35.235001,
#   'SolarPowerCapacity': 47.832161,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 4,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 45,
#   'NumberSolarPanels': 966},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '326',
#   'CapacityGe100MW': 787.0,
#   'CapacityLt100MW': 33.0905,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 80.716003,
#   'SolarPowerCapacity': 53.646568,
#   'NumberGenerationUnitsGe100MW': 2,
#   'NumberGenerationUnitsLt100MW': 7,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 121,
#   'NumberSolarPanels': 1460},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '329',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 12.048,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 9.049,
#   'SolarPowerCapacity': 4.73112,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 4,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 19,
#   'NumberSolarPanels': 690},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '330',
#   'CapacityGe100MW': 264.0,
#   'CapacityLt100MW': 22.497499,
#   'OffshoreWindCapacity': 21.0,
#   'OnshoreWindCapacity': 44.056999,
#   'SolarPowerCapacity': 32.511688,
#   'NumberGenerationUnitsGe100MW': 1,
#   'NumberGenerationUnitsLt100MW': 96,
#   'NumberOffshoreWindGenerators': 7,
#   'NumberOnshoreWindGenerators': 110,
#   'NumberSolarPanels': 1578},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '336',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 6.952,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 9.9255,
#   'SolarPowerCapacity': 4.08429,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 5,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 27,
#   'NumberSolarPanels': 745},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '340',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 10.964,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 6.833,
#   'SolarPowerCapacity': 4.07959,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 6,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 10,
#   'NumberSolarPanels': 704},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '350',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 3.266,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 5.448,
#   'SolarPowerCapacity': 5.2519,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 3,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 19,
#   'NumberSolarPanels': 830},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '360',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 16.125999,
#   'OffshoreWindCapacity': 372.600006,
#   'OnshoreWindCapacity': 273.235992,
#   'SolarPowerCapacity': 109.802559,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 3,
#   'NumberOffshoreWindGenerators': 162,
#   'NumberOnshoreWindGenerators': 204,
#   'NumberSolarPanels': 1027},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '370',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 53.693199,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 68.656998,
#   'SolarPowerCapacity': 60.759281,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 29,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 86,
#   'NumberSolarPanels': 1925},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '376',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 38.703999,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 58.7575,
#   'SolarPowerCapacity': 48.357121,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 7,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 142,
#   'NumberSolarPanels': 1503},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '390',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 101.041,
#   'OffshoreWindCapacity': 604.799988,
#   'OnshoreWindCapacity': 17.848499,
#   'SolarPowerCapacity': 8.91593,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 11,
#   'NumberOffshoreWindGenerators': 72,
#   'NumberOnshoreWindGenerators': 58,
#   'NumberSolarPanels': 1219},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '400',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 65.410004,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 37.1096,
#   'SolarPowerCapacity': 22.48126,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 5,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 86,
#   'NumberSolarPanels': 1109},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '410',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 7.293,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 13.618,
#   'SolarPowerCapacity': 8.81633,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 7,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 26,
#   'NumberSolarPanels': 1274},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '420',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 36.063999,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 31.181999,
#   'SolarPowerCapacity': 12.95209,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 19,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 56,
#   'NumberSolarPanels': 1261},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '430',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 27.976999,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 15.779,
#   'SolarPowerCapacity': 9.43442,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 13,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 35,
#   'NumberSolarPanels': 1563},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '440',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 5.295,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 24.950001,
#   'SolarPowerCapacity': 3.61796,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 5,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 16,
#   'NumberSolarPanels': 521},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '450',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 16.313,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 28.993,
#   'SolarPowerCapacity': 3.70213,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 4,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 40,
#   'NumberSolarPanels': 665},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '461',
#   'CapacityGe100MW': 372.0,
#   'CapacityLt100MW': 122.183998,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 11.136,
#   'SolarPowerCapacity': 17.40719,
#   'NumberGenerationUnitsGe100MW': 1,
#   'NumberGenerationUnitsLt100MW': 35,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 16,
#   'NumberSolarPanels': 1815},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '479',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 26.481001,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 34.608002,
#   'SolarPowerCapacity': 45.207561,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 16,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 52,
#   'NumberSolarPanels': 1394},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '480',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 18.257999,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 26.441999,
#   'SolarPowerCapacity': 5.78635,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 10,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 55,
#   'NumberSolarPanels': 971},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '482',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': None,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 43.806,
#   'SolarPowerCapacity': 2.41538,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 0,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 67,
#   'NumberSolarPanels': 358},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '492',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 0.75,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 12.026,
#   'SolarPowerCapacity': 1.52654,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 1,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 9,
#   'NumberSolarPanels': 311},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '510',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 44.561001,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 40.714001,
#   'SolarPowerCapacity': 10.90487,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 24,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 67,
#   'NumberSolarPanels': 1640},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '530',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 27.809,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 92.594498,
#   'SolarPowerCapacity': 7.19222,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 11,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 64,
#   'NumberSolarPanels': 891},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '540',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 79.115997,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 14.0145,
#   'SolarPowerCapacity': 39.104279,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 14,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 35,
#   'NumberSolarPanels': 2020},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '550',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 76.496002,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 175.636002,
#   'SolarPowerCapacity': 9.67415,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 40,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 337,
#   'NumberSolarPanels': 1484},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '561',
#   'CapacityGe100MW': 401.0,
#   'CapacityLt100MW': 70.780998,
#   'OffshoreWindCapacity': 776.0,
#   'OnshoreWindCapacity': 81.681396,
#   'SolarPowerCapacity': 15.11247,
#   'NumberGenerationUnitsGe100MW': 1,
#   'NumberGenerationUnitsLt100MW': 14,
#   'NumberOffshoreWindGenerators': 220,
#   'NumberOnshoreWindGenerators': 69,
#   'NumberSolarPanels': 2116},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '563',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': None,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 1.98,
#   'SolarPowerCapacity': 0.90108,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 0,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 3,
#   'NumberSolarPanels': 164},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '573',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 16.2997,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 99.787003,
#   'SolarPowerCapacity': 69.200623,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 18,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 137,
#   'NumberSolarPanels': 1936},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '575',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 10.796,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 61.110001,
#   'SolarPowerCapacity': 9.34912,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 14,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 97,
#   'NumberSolarPanels': 1439},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '580',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 4.928,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 84.558998,
#   'SolarPowerCapacity': 309.907318,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 11,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 108,
#   'NumberSolarPanels': 1659},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '607',
#   'CapacityGe100MW': 427.0,
#   'CapacityLt100MW': 28.422001,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 2.278,
#   'SolarPowerCapacity': 8.7194,
#   'NumberGenerationUnitsGe100MW': 1,
#   'NumberGenerationUnitsLt100MW': 5,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 8,
#   'NumberSolarPanels': 1008},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '615',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 40.910999,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 3.59,
#   'SolarPowerCapacity': 16.73702,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 6,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 14,
#   'NumberSolarPanels': 2528},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '621',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 12.15,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 34.012001,
#   'SolarPowerCapacity': 15.15548,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 9,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 41,
#   'NumberSolarPanels': 2088},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '630',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 13.26,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 53.601501,
#   'SolarPowerCapacity': 205.765457,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 10,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 74,
#   'NumberSolarPanels': 3530},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '657',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 106.522003,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 136.735107,
#   'SolarPowerCapacity': 34.139568,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 15,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 147,
#   'NumberSolarPanels': 2217},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '661',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 43.945999,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 230.267593,
#   'SolarPowerCapacity': 188.470886,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 8,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 195,
#   'NumberSolarPanels': 1877},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '665',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 26.59,
#   'OffshoreWindCapacity': 45.200001,
#   'OnshoreWindCapacity': 154.822006,
#   'SolarPowerCapacity': 44.462971,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 12,
#   'NumberOffshoreWindGenerators': 12,
#   'NumberOnshoreWindGenerators': 198,
#   'NumberSolarPanels': 925},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '671',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': None,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 62.381001,
#   'SolarPowerCapacity': 4.30747,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 0,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 95,
#   'NumberSolarPanels': 755},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '706',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 0.78,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 18.845501,
#   'SolarPowerCapacity': 8.82965,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 6,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 46,
#   'NumberSolarPanels': 1581},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '707',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 26.108999,
#   'OffshoreWindCapacity': 399.600006,
#   'OnshoreWindCapacity': 52.667999,
#   'SolarPowerCapacity': 31.1691,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 6,
#   'NumberOffshoreWindGenerators': 111,
#   'NumberOnshoreWindGenerators': 91,
#   'NumberSolarPanels': 1005},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '710',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 21.9506,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 34.969002,
#   'SolarPowerCapacity': 8.09361,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 22,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 58,
#   'NumberSolarPanels': 1454},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '727',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 5.3,
#   'OffshoreWindCapacity': 5.0,
#   'OnshoreWindCapacity': 15.707,
#   'SolarPowerCapacity': 3.65405,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 3,
#   'NumberOffshoreWindGenerators': 10,
#   'NumberOnshoreWindGenerators': 17,
#   'NumberSolarPanels': 800},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '730',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 85.824997,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 248.167007,
#   'SolarPowerCapacity': 56.886108,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 9,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 158,
#   'NumberSolarPanels': 2095},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '740',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 113.737999,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 20.341,
#   'SolarPowerCapacity': 29.282721,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 14,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 49,
#   'NumberSolarPanels': 2960},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '741',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': None,
#   'OffshoreWindCapacity': 23.1,
#   'OnshoreWindCapacity': 11.399,
#   'SolarPowerCapacity': 1.52522,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 0,
#   'NumberOffshoreWindGenerators': 10,
#   'NumberOnshoreWindGenerators': 27,
#   'NumberSolarPanels': 264},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '746',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 3.8976,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 17.057501,
#   'SolarPowerCapacity': 10.82346,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 7,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 20,
#   'NumberSolarPanels': 2009},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '751',
#   'CapacityGe100MW': 760.0,
#   'CapacityLt100MW': 81.612,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 11.4315,
#   'SolarPowerCapacity': 36.52309,
#   'NumberGenerationUnitsGe100MW': 2,
#   'NumberGenerationUnitsLt100MW': 22,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 35,
#   'NumberSolarPanels': 5271},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '756',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 29.681,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 67.393501,
#   'SolarPowerCapacity': 9.40413,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 17,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 61,
#   'NumberSolarPanels': 1368},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '760',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 51.096001,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 498.461914,
#   'SolarPowerCapacity': 51.4132,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 25,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 357,
#   'NumberSolarPanels': 2388},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '766',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 6.639,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 28.003,
#   'SolarPowerCapacity': 10.89163,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 5,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 67,
#   'NumberSolarPanels': 2182},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '773',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 13.801,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 78.609497,
#   'SolarPowerCapacity': 30.259359,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 9,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 174,
#   'NumberSolarPanels': 712},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '779',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 32.237,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 117.408798,
#   'SolarPowerCapacity': 51.709579,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 26,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 176,
#   'NumberSolarPanels': 2194},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '787',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 27.663,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 184.866501,
#   'SolarPowerCapacity': 54.14761,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 22,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 536,
#   'NumberSolarPanels': 2039},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '791',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 107.100998,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 61.719002,
#   'SolarPowerCapacity': 20.133739,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 36,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 93,
#   'NumberSolarPanels': 3186},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '810',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 49.823002,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 92.500198,
#   'SolarPowerCapacity': 33.40572,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 20,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 102,
#   'NumberSolarPanels': 1117},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '813',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 39.143002,
#   'OffshoreWindCapacity': 7.6,
#   'OnshoreWindCapacity': 49.080002,
#   'SolarPowerCapacity': 28.020081,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 20,
#   'NumberOffshoreWindGenerators': 3,
#   'NumberOnshoreWindGenerators': 93,
#   'NumberSolarPanels': 1699},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '820',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 20.722,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 140.524002,
#   'SolarPowerCapacity': 39.958599,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 17,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 150,
#   'NumberSolarPanels': 1508},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '825',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 0.0536,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 0.18,
#   'SolarPowerCapacity': 7.4953,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 10,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 1,
#   'NumberSolarPanels': 139},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '840',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 18.856001,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 48.720001,
#   'SolarPowerCapacity': 6.1725,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 14,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 79,
#   'NumberSolarPanels': 1378},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '846',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 10.663,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 104.3703,
#   'SolarPowerCapacity': 23.92795,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 15,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 78,
#   'NumberSolarPanels': 1588},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '849',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 20.912001,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 194.304504,
#   'SolarPowerCapacity': 9.92376,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 13,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 203,
#   'NumberSolarPanels': 1533},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '851',
#   'CapacityGe100MW': 410.0,
#   'CapacityLt100MW': 53.541,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 159.233002,
#   'SolarPowerCapacity': 18.33329,
#   'NumberGenerationUnitsGe100MW': 1,
#   'NumberGenerationUnitsLt100MW': 31,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 197,
#   'NumberSolarPanels': 3532},
#  {'Month': '2022-07-01T00:00:00',
#   'MunicipalityNo': '860',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 96.491997,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': 123.207001,
#   'SolarPowerCapacity': 16.999491,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 21,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 247,
#   'NumberSolarPanels': 1821},
#  {'Month': '2022-06-01T00:00:00',
#   'MunicipalityNo': '1',
#   'CapacityGe100MW': None,
#   'CapacityLt100MW': 0.18,
#   'OffshoreWindCapacity': None,
#   'OnshoreWindCapacity': None,
#   'SolarPowerCapacity': None,
#   'NumberGenerationUnitsGe100MW': 0,
#   'NumberGenerationUnitsLt100MW': 9,
#   'NumberOffshoreWindGenerators': 0,
#   'NumberOnshoreWindGenerators': 0,
#   'NumberSolarPanels': 0}]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3.  Convert json data into *pandas* data frame.

# %%
# Write your code here
# Out:
#                                                     0
# 0   b'[{\n    "genus": "Malus",\n    "name": "Appl...
# 1   b'\n        "carbohydrates": 11.4,\n        "p...
# 2   b'}, {\n    "genus": "Prunus",\n    "name": "A...
# 3   b'ns": {\n        "carbohydrates": 3.9,\n     ...
# 4   b'  }\n}, {\n    "genus": "Musa",\n    "name":...
# ..                                                ...
# 59  b'       "calories": 74,\n        "sugar": 2.6...
# 60  b'"Anacardiaceae",\n    "order": "0",\n    "nu...
# 61  b'   "calories": 0,\n        "sugar": 0\n    }...
# 62  b'"Cucurbitaceae",\n    "order": "Cucurbitales...
# 63  b'at": 0.2,\n        "calories": 30,\n        ...
#
# [64 rows x 1 columns]

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Author
#
# [Svitlana Kramar](https://www.linkedin.com/in/svitlana-kramar?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01)
#
# Svitlana is a master’s degree Data Science and Analytics student at University of Calgary, who enjoys travelling, learning new languages and cultures and loves spreading her passion for Data Science.

# %% [markdown]
# Copyright © 2020 IBM Corporation. All rights reserved.
